# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pro_stats_work = pd.read_csv("QBStats_all.csv")
pro_stats_work
# Out:
#                                   qb  att  cmp    yds  ypa  td  int   lg  \
# 0           Boomer EsiasonB. Esiason   38   25  237.0  6.2   0    0   20
# 1            Jim HarbaughJ. Harbaugh   25   16  196.0  7.8   2    1  35t
# 2               Paul JustinP. Justin    8    5   53.0  6.6   0    0   30
# 3               Jeff GeorgeJ. George   35   16  215.0  6.1   0    0   55
# 4            Kerry CollinsK. Collins   31   17  198.0  6.4   2    0   30
# ...                              ...  ...  ...    ...  ...  ..  ...  ...
# 13183             Alex SmithA. Smith   28   21  264.0  9.4   2    1   42
# 13184         Philip RiversP. Rivers   38   22  269.0  7.1   2    2   23
# 13185        Russell WilsonR. Wilson   32   19  258.0  8.1   1    0   42
# 13186        Trevone BoykinT. Boykin    6    4   42.0  7.0   0    0   19
# 13187  Colin KaepernickC. Kaepernick   22   17  215.0  9.8   1    0   29
#
#        sack  loss   rate  game_points home_away  year
# ...

# %%
sorted_dataA = pro_stats_work.groupby(['qb','year']).sum()
sorted_dataA = sorted_dataA.drop(columns = ["ypa","rate"])

sorted_dataB = pro_stats_work.groupby(['qb','year']).mean()
sorted_dataB = sorted_dataB.drop(columns = ["att","cmp","yds","td","int","sack","loss","game_points"])

sorted_dataA["ypa"] = sorted_dataB["ypa"]
sorted_dataA["rate"] = sorted_dataB["rate"]

pro_stats = sorted_dataA.query("att > 350")

# %%
pro_stats
# Out:
#                                     att  cmp     yds  td  int  sack   loss  \
# qb                            year
# A.J. FeeleyA. Feeley          2004  356  191  1893.0  11   15  23.0  136.0
# Aaron BrooksA. Brooks         2001  558  312  3832.0  26   22  50.0  330.0
#                               2002  528  283  3572.0  27   15  36.0  236.0
#                               2003  518  306  3546.0  24    8  34.0  195.0
#                               2004  542  309  3810.0  21   16  41.0  223.0
# ...                                 ...  ...     ...  ..  ...   ...    ...
# Vinny TestaverdeV. Testaverde 1998  421  259  3256.0  29    7  19.0  140.0
#                               2000  590  328  3732.0  21   25  13.0   71.0
#                               2001  441  260  2752.0  15   14  18.0  122.0
#                               2004  495  297  3532.0  17   20  34.0  182.0
# Warren MoonW. Moon            1997  528  313  3678.0  25   16  30.0  192.0
#
# ...

# %%
top_seasons = pro_stats.query("rate > 80")
top_seasons
# Out:
#                                     att  cmp     yds  td  int  sack   loss  \
# qb                            year
# Aaron BrooksA. Brooks         2002  528  283  3572.0  27   15  36.0  236.0
#                               2003  518  306  3546.0  24    8  34.0  195.0
#                               2004  542  309  3810.0  21   16  41.0  223.0
# Aaron RodgersA. Rodgers       2008  536  341  4038.0  28   13  34.0  231.0
#                               2009  541  350  4434.0  30    7  50.0  306.0
# ...                                 ...  ...     ...  ..  ...   ...    ...
# Tyrod TaylorT. Taylor         2015  380  242  3035.0  20    6  36.0  212.0
#                               2016  436  269  3023.0  17    6  42.0  192.0
# Vinny TestaverdeV. Testaverde 1996  549  325  4177.0  33   19  34.0  270.0
#                               1998  421  259  3256.0  29    7  19.0  140.0
# Warren MoonW. Moon            1997  528  313  3678.0  25   16  30.0  192.0
#
# ...

# %%
stats_1996 = pro_stats.query("year == 1996")
stats_1997 = pro_stats.query("year == 1997")
stats_1998 = pro_stats.query("year == 1998")
stats_1999 = pro_stats.query("year == 1999")
stats_2000 = pro_stats.query("year == 2000")
stats_2001 = pro_stats.query("year == 2001")
stats_2002 = pro_stats.query("year == 2002")
stats_2003 = pro_stats.query("year == 2003")
stats_2004 = pro_stats.query("year == 2004")
stats_2005 = pro_stats.query("year == 2005")
stats_2006 = pro_stats.query("year == 2006")
stats_2007 = pro_stats.query("year == 2007")
stats_2008 = pro_stats.query("year == 2008")
stats_2009 = pro_stats.query("year == 2009")
stats_2010 = pro_stats.query("year == 2010")
stats_2011 = pro_stats.query("year == 2011")
stats_2012 = pro_stats.query("year == 2012")
stats_2013 = pro_stats.query("year == 2013")
stats_2014 = pro_stats.query("year == 2014")
stats_2015 = pro_stats.query("year == 2015")
stats_2016 = pro_stats.query("year == 2016")

plt.figure(figsize=(10,8)) 

plt.subplot(3,7,1)
plt.hist(stats_1996["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,2)
plt.hist(stats_1997["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,3)
plt.hist(stats_1998["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,4)
plt.title("Distribution of Passer Ratings")
plt.hist(stats_1999["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,5)
plt.hist(stats_2000["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,6)
plt.hist(stats_2001["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,7)
plt.hist(stats_2002["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,8)
plt.hist(stats_2003["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.ylabel("Frequency")
plt.subplot(3,7,9)
plt.hist(stats_2004["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,10)
plt.hist(stats_2005["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,11)
plt.hist(stats_2006["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,12)        
plt.hist(stats_2007["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,13)
plt.hist(stats_2008["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,14)
plt.hist(stats_2009["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,15)
plt.hist(stats_2010["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,16)
plt.hist(stats_2011["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,17)
plt.hist(stats_2012["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,18)
plt.hist(stats_2013["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.xlabel("Passer Rating")
plt.subplot(3,7,19)
plt.hist(stats_2014["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,20)
plt.hist(stats_2015["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
plt.subplot(3,7,21)
plt.hist(stats_2016["rate"])
plt.xlim(50, 120)
plt.ylim(0, 9)
# Out:
# (0.0, 9.0)
