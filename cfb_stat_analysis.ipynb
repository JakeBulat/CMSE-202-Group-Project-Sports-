# %%
import pandas as pd
import numpy as np
import math

# %%
#This data for current college QB's can be used to test in our model to predict which Quarterbacks will be successful in future
qb_22 = pd.read_csv('cfb_qb22.csv')
qb_21 = pd.read_csv('cfb_qb21.csv')
qb_20 = pd.read_csv('cfb_qb20.csv')
qb_19 = pd.read_csv('cfb_qb19.csv')
qb_18 = pd.read_csv('cfb_qb18.csv')
qb_17 = pd.read_csv('cfb_qb17.csv')
qb_16 = pd.read_csv('cfb_qb16.csv')
qb_15 = pd.read_csv('cfb_qb15.csv')
qb_14 = pd.read_csv('cfb_qb14.csv')

# %%
dataframes = [qb_22, qb_21, qb_20, qb_19, qb_18, qb_17, qb_16, qb_15, qb_14]
qbs = pd.concat(dataframes)
under200 = qbs[qbs['attempts'] <= 200].index
qbs.drop(under200, inplace = True)
qbs
# Out:
#                player  player_id position   team_name  player_game_count  \
# 0         Will Rogers     124184       QB  MISS STATE                 13
# 1      Kyle Vantrease      55029       QB  GA SOUTHRN                 13
# 2         Austin Reed     111760       QB  W KENTUCKY                 14
# 3   Michael Penix Jr.      82134       QB  WASHINGTON                 13
# 4          Drake Maye     143969       QB  N CAROLINA                 14
# ..                ...        ...      ...         ...                ...
# 60        Cooper Rush      12324       QB  C MICHIGAN                 12
# 61     Austin Grammer      23315       QB   MIDDLE TN                 12
# 62         Tanner Lee      38321       QB      TULANE                 10
# 63        Kevin Hogan      10796       QB    STANFORD                 12
# 64     Marcus Mariota       9435       QB      OREGON                 12
#
#     accuracy_percent  aimed_passes  attempts  avg_depth_of_target  \
# ...
