# %%
import pandas as pd
import numpy as np
import math

nfl_17 = pd.read_csv('nfl_qb17.csv')
nfl_18 = pd.read_csv('nfl_qb18.csv')
nfl_19 = pd.read_csv('nfl_qb19.csv')
nfl_20 = pd.read_csv('nfl_qb20.csv')
nfl_21 = pd.read_csv('nfl_qb21.csv')
nfl_22 = pd.read_csv('nfl_qb22.csv')

# %%
dataframes = [nfl_22, nfl_21, nfl_20, nfl_19, nfl_18, nfl_17]
nfl_qbs = pd.concat(dataframes)
under200 = nfl_qbs[nfl_qbs['attempts'] <= 200].index
nfl_qbs.drop(under200, inplace = True)
nfl_qbs
# Out:
#              player  player_id position team_name  player_game_count  \
# 0         Tom Brady        698       QB        TB                 17
# 1    Justin Herbert      28237       QB       LAC                 17
# 2   Patrick Mahomes      11765       QB        KC                 17
# 3      Kirk Cousins       7102       QB       MIN                 17
# 4        Joe Burrow      28022       QB       CIN                 16
# ..              ...        ...      ...       ...                ...
# 28    Brett Hundley       9580       QB        GB                 11
# 29    Carson Palmer       1317       QB       ARZ                  7
# 30    Aaron Rodgers       2241       QB        GB                  7
# 31    C.J. Beathard      11859       QB        SF                  6
# 32       Tom Savage       8770       QB       HST                  8
#
#     accuracy_percent  aimed_passes  attempts  avg_depth_of_target  \
# 0               75.7           687       733                  7.3
# 1               79.0           637       699                  7.0
# 2               77.8           591       647                  7.7
# 3               76.0           584       643                  8.0
# 4               77.5           561       606                  7.5
# ..               ...           ...       ...                  ...
# 28              73.2           284       316                  7.8
# 29              71.0           252       267                  9.8
# 30              76.3           215       238                  7.3
# 31              69.2           201       224                  8.1
# 32              67.8           202       223                 10.2
#
#     avg_time_to_throw  ...  sack_percent  sacks  scrambles  spikes  \
# 0                2.29  ...           2.9     22          4       3
# 1                2.74  ...           5.0     38         23       2
# 2                2.85  ...           3.6     26         46       0
# 3                2.70  ...           6.6     46         12       3
# 4                2.49  ...           6.1     41         27       1
# ..                ...  ...           ...    ...        ...     ...
# 28               3.00  ...           7.9     29         22       0
# 29               2.45  ...           7.6     22          1       0
# 30               2.77  ...           8.0     22         16       1
# 31               2.59  ...           7.4     19         13       1
# 32               2.56  ...           8.5     21          2       1
#
#     thrown_aways  touchdowns  turnover_worthy_plays  twp_rate  yards  ypa
# 0             32          25                     20       2.5   4703  6.4
# 1             25          25                     13       1.6   4749  6.8
# 2             40          41                     18       2.3   5251  8.1
# 3             33          29                     23       3.1   4547  7.1
# 4             19          35                     16       2.2   4474  7.4
# ..           ...         ...                    ...       ...    ...  ...
# 28            24           9                     15       3.9   1836  5.8
# 29             7           9                     18       5.8   1978  7.4
# 30            16          16                     10       3.3   1675  7.0
# 31             7           4                     11       4.2   1430  6.4
# 32             7           5                     14       5.2   1412  6.3
#
# [198 rows x 42 columns]
